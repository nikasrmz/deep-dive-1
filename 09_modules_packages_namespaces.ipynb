# %%
def func():
    a = 10
    print(locals())

# %%
func()
# Out:
# {'a': 10}

# %%
globals() is locals()
# Out:
# True

# %%
import math

# %%
math
# Out:
# <module 'math' (built-in)>

# %%
import fractions

# %%
fractions
# Out:
# <module 'fractions' from 'c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\.conda\\Lib\\fractions.py'>

# %%
import sys

# %%
sys.modules['math']
# Out:
# <module 'math' (built-in)>

# %%
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module '_frozen_importlib' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  'winreg': <module 'winreg' (built-in)>,
#  '_io': <module '_io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'nt': <module 'nt' (built-in)>,
#  '_frozen_importlib_external': <module '_frozen_importlib_external' (frozen)>,
#  'time': <module 'time' (built-in)>,
#  'zipimport': <module 'zipimport' (frozen)>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'codecs': <module 'codecs' (frozen)>,
#  'encodings.aliases': <module 'encodings.aliases' from 'c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\.conda\\Lib\\encodings\\aliases.py'>,
# ...

# %%
math.__dict__
# Out:
# {'__name__': 'math',
#  '__doc__': 'This module provides access to the mathematical functions\ndefined by the C standard.',
#  '__package__': '',
#  '__loader__': _frozen_importlib.BuiltinImporter,
#  '__spec__': ModuleSpec(name='math', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'),
#  'acos': <function math.acos(x, /)>,
#  'acosh': <function math.acosh(x, /)>,
#  'asin': <function math.asin(x, /)>,
#  'asinh': <function math.asinh(x, /)>,
#  'atan': <function math.atan(x, /)>,
#  'atan2': <function math.atan2(y, x, /)>,
#  'atanh': <function math.atanh(x, /)>,
#  'cbrt': <function math.cbrt(x, /)>,
#  'ceil': <function math.ceil(x, /)>,
#  'copysign': <function math.copysign(x, y, /)>,
#  'cos': <function math.cos(x, /)>,
#  'cosh': <function math.cosh(x, /)>,
#  'degrees': <function math.degrees(x, /)>,
#  'dist': <function math.dist(p, q, /)>,
#  'erf': <function math.erf(x, /)>,
#  'erfc': <function math.erfc(x, /)>,
#  'exp': <function math.exp(x, /)>,
# ...

# %%
import sys

# %%
sys
# Out:
# <module 'sys' (built-in)>

# %%
import collections

# %%
collections
# Out:
# <module 'collections' from 'c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\.conda\\Lib\\collections\\__init__.py'>

# %%
import sys

# %%
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module '_frozen_importlib' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  'winreg': <module 'winreg' (built-in)>,
#  '_io': <module '_io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'nt': <module 'nt' (built-in)>,
#  '_frozen_importlib_external': <module '_frozen_importlib_external' (frozen)>,
#  'time': <module 'time' (built-in)>,
#  'zipimport': <module 'zipimport' (frozen)>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'codecs': <module 'codecs' (frozen)>,
#  'encodings.aliases': <module 'encodings.aliases' from 'c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\.conda\\Lib\\encodings\\aliases.py'>,
# ...

# %%
sys.path
# Out:
# ['c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\.conda\\python312.zip',
#  'c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\.conda\\DLLs',
#  'c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\.conda\\Lib',
#  'c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\.conda',
#  '',
#  'c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\.conda\\Lib\\site-packages',
#  'c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\.conda\\Lib\\site-packages\\win32',
#  'c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\.conda\\Lib\\site-packages\\win32\\lib',
#  'c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\.conda\\Lib\\site-packages\\Pythonwin']

# %%
import importlib

# %%
sys.meta_path
# Out:
# ...
#  _frozen_importlib.BuiltinImporter,
#  _frozen_importlib.FrozenImporter,
#  _frozen_importlib_external.PathFinder,
# ...

# %%
import math

# %%
math.__spec__
# Out:
# ModuleSpec(name='math', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in')

# %%
with open("modula.py", "w") as code_file:
    code_file.write("print('running modula')\n")
    code_file.write("a = 100\n")

# %%
import modula
# Out:
# running modula

# %%
importlib.util.find_spec('modula')
# Out:
# ModuleSpec(name='modula', loader=<_frozen_importlib_external.SourceFileLoader object at 0x0000021CD59439B0>, origin='c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\modula.py')

# %%
'modula' in globals()
# Out:
# True

# %%
globals()['modula']
# Out:
# <module 'modula' from 'c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\modula.py'>

# %%
modula
# Out:
# <module 'modula' from 'c:\\Users\\nsharmazanashvili\\Desktop\\Playground\\deep-dive-1\\modula.py'>

# %%
import os

# %%
ext_module_path = os.environ["HOMEPATH"]

# %%
ext_module_path
# Out:
# '\\Users\\nsharmazanashvili'

# %%
file_abs_path = os.path.join(ext_module_path, "modula2.py")
